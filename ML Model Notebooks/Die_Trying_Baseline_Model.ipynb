# %%
# ==========================================
# UNIVERSAL SETUP & DATA LOADER
# ==========================================
import os
import shutil
import gdown
from google.colab import drive

# 1. Mount Drive (For saving results later)
print("🔌 Mounting Google Drive...")
drive.mount('/content/drive')

# 2. Configuration
FILE_ID = '1aESAhJMB3ur3kpgqoUetGvQf6l2wuAiW'
DOWNLOAD_OUTPUT = '/content/Final_Dataset.zip'
EXTRACT_DIR = '/content/Final_Dataset_Extracted'

# 3. Download
if not os.path.exists(DOWNLOAD_OUTPUT):
    print(f"⬇️  Downloading dataset...")
    gdown.download(f'https://drive.google.com/uc?id={FILE_ID}', DOWNLOAD_OUTPUT, quiet=False)
else:
    print("✅ Zip file already exists.")

# 4. Extract
if not os.path.exists(EXTRACT_DIR):
    print(f"📦 Extracting...")
    shutil.unpack_archive(DOWNLOAD_OUTPUT, EXTRACT_DIR)
else:
    print("✅ Already extracted.")

# 5. Locate the actual Data Root (Fixing the nesting issue)
DATASET_ROOT = os.path.join(EXTRACT_DIR, 'Final_Dataset', 'Final_Dataset')
if not os.path.exists(os.path.join(DATASET_ROOT, 'Train')):
    # Fallback search if folder structure changes
    for root, dirs, files in os.walk(EXTRACT_DIR):
        if 'Train' in dirs:
            DATASET_ROOT = root
            break

print(f"✅ DATASET READY AT: {DATASET_ROOT}")
# Save this path to a global variable for the training scripts
os.environ['NXP_DATASET_ROOT'] = DATASET_ROOT
# Out:
# 🔌 Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ⬇️  Downloading dataset...
# Downloading...
# From (original): https://drive.google.com/uc?id=1aESAhJMB3ur3kpgqoUetGvQf6l2wuAiW
# From (redirected): https://drive.google.com/uc?id=1aESAhJMB3ur3kpgqoUetGvQf6l2wuAiW&confirm=t&uuid=31ebb0ca-286e-4398-8d11-7bfe7034c7b3
# To: /content/Final_Dataset.zip
# 100%|██████████| 810M/810M [00:12<00:00, 66.4MB/s]
# 📦 Extracting...
# ✅ DATASET READY AT: /content/Final_Dataset_Extracted/Final_Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models, Input, Model
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# --- CONFIG ---
MODEL_NAME = "MobileNetV2_Focal_HardMiner"
DATA_DIR = os.environ.get('NXP_DATASET_ROOT')

BASE_DIR = f'./NXP_Results_{MODEL_NAME}'
CKPT_DIR = os.path.join(BASE_DIR, 'Checkpoints')
MODEL_DIR = os.path.join(BASE_DIR, 'Model_Files')
REPORT_DIR = os.path.join(BASE_DIR, 'Reports')
for d in [CKPT_DIR, MODEL_DIR, REPORT_DIR]: os.makedirs(d, exist_ok=True)

# 224x224 is MANDATORY for seeing 1-pixel bridges
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 25

# --- DATA ---
train_ds = tf.keras.utils.image_dataset_from_directory(os.path.join(DATA_DIR, 'Train'), image_size=IMG_SIZE, batch_size=BATCH_SIZE, color_mode='grayscale', shuffle=True, seed=123)
val_ds = tf.keras.utils.image_dataset_from_directory(os.path.join(DATA_DIR, 'Validation'), image_size=IMG_SIZE, batch_size=BATCH_SIZE, color_mode='grayscale', shuffle=False)
class_names = train_ds.class_names

# --- 1. THE SECRET WEAPON: FOCAL LOSS ---
def focal_loss(gamma=4.0, alpha=0.25):
    # gamma: Higher = Focus more on hard examples (Bridges/Opens)
    # alpha: Balance factor for classes
    def focal_loss_fixed(y_true, y_pred):
        # Sparse to One-Hot
        y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=len(class_names))
        y_true = tf.cast(y_true, tf.float32)

        # Clip to prevent NaN
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1. - 1e-7)

        # Calculate Cross Entropy
        cross_entropy = -y_true * tf.math.log(y_pred)

        # Calculate Focal Weight: (1 - p)^gamma
        weight = alpha * y_true * tf.pow((1 - y_pred), gamma)

        # Final Loss
        loss = weight * cross_entropy
        return tf.reduce_sum(loss, axis=1)
    return focal_loss_fixed

# --- MODEL ---
def build_model():
    inputs = Input(shape=IMG_SIZE + (1,))
    x = layers.Rescaling(1./255)(inputs)

    # Simple Augmentation (Since dataset is already rotated)
    x = layers.RandomFlip("horizontal_and_vertical")(x)
    x = layers.RandomContrast(0.2)(x) # Helps distinct Bridges from Background

    # Virtual RGB
    x = layers.Conv2D(3, 1, padding='same', use_bias=False)(x)

    # Load MobileNetV2 (0.75)
    base_model = tf.keras.applications.MobileNetV2(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet',
        alpha=0.75
    )

    # PARTIAL UNFREEZE:
    # We freeze the bottom (shapes) and unfreeze the top (textures/details)
    base_model.trainable = True
    # Freeze the first 100 layers (Structural features like lines/circles)
    # Unfreeze the last 50 layers (Specific features like "Jagged Lines")
    for layer in base_model.layers[:-50]:
        layer.trainable = False

    x = base_model(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.2)(x)
    # Softmax is REQUIRED for Focal Loss stability
    outputs = layers.Dense(len(class_names), activation='softmax')(x)

    return Model(inputs, outputs)

model = build_model()

# Low LR because we are fine-tuning
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)

model.compile(
    optimizer=optimizer,
    loss=focal_loss(gamma=4.0, alpha=0.25), # Using the Custom Loss
    metrics=['accuracy']
)

# --- TRAIN ---
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(CKPT_DIR, "best_model.keras"), save_best_only=True, monitor='val_accuracy'),
    tf.keras.callbacks.CSVLogger(os.path.join(REPORT_DIR, "log.csv"))
]

print(f"🚀 Training with Focal Loss (Gamma=4.0) to hunt Bridges/Opens...")
history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS, callbacks=callbacks)

# --- REPORT ---
model.load_weights(os.path.join(CKPT_DIR, "best_model.keras"))
y_pred = np.argmax(model.predict(val_ds), axis=1)
y_true = np.concatenate([y for x, y in val_ds], axis=0)

print("\n--- CLASSIFICATION REPORT ---")
print(classification_report(y_true, y_pred, target_names=class_names))
with open(os.path.join(REPORT_DIR, "report.txt"), "w") as f: f.write(classification_report(y_true, y_pred, target_names=class_names))

print("💾 Converting to TFLite...")
def rep_data():
    for img, _ in train_ds.take(100): yield [tf.cast(img, tf.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = rep_data
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_model = converter.convert()

with open(os.path.join(MODEL_DIR, f"{MODEL_NAME}.tflite"), 'wb') as f: f.write(tflite_model)

hex_lines = [f"0x{b:02x}" for b in tflite_model]
cc_code = f'#include "{MODEL_NAME}.h"\nconst unsigned int g_model_len = {len(tflite_model)};\nconst unsigned char g_model[] __attribute__((aligned(16))) = {{\n' + ", ".join(hex_lines) + "\n};\n"
with open(os.path.join(MODEL_DIR, f"{MODEL_NAME}.cc"), 'w') as f: f.write(cc_code)
with open(os.path.join(MODEL_DIR, f"{MODEL_NAME}.h"), 'w') as f: f.write(f'extern const unsigned int g_model_len;\nextern const unsigned char g_model[];\n')

print(f"✅ {MODEL_NAME} Complete!")
# Out:
# Found 15996 files belonging to 8 classes.
# Found 4433 files belonging to 8 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.75_224_no_top.h5
# 5903360/5903360 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 🚀 Training with Focal Loss (Gamma=4.0) to hunt Bridges/Opens...
# Epoch 1/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 113s 145ms/step - accuracy: 0.6812 - loss: 0.0959 - val_accuracy: 0.3521 - val_loss: 0.3829
# Epoch 2/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.8680 - loss: 0.0218 - val_accuracy: 0.4893 - val_loss: 0.4401
# Epoch 3/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.9048 - loss: 0.0143 - val_accuracy: 0.7072 - val_loss: 0.1027
# Epoch 4/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.9183 - loss: 0.0108 - val_accuracy: 0.7882 - val_loss: 0.0502
# Epoch 5/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 63ms/step - accuracy: 0.9322 - loss: 0.0084 - val_accuracy: 0.8238 - val_loss: 0.0430
# Epoch 6/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9388 - loss: 0.0069 - val_accuracy: 0.8642 - val_loss: 0.0231
# Epoch 7/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.9486 - loss: 0.0060 - val_accuracy: 0.8897 - val_loss: 0.0243
# Epoch 8/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 41s 66ms/step - accuracy: 0.9513 - loss: 0.0049 - val_accuracy: 0.9053 - val_loss: 0.0169
# Epoch 9/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 43s 69ms/step - accuracy: 0.9543 - loss: 0.0047 - val_accuracy: 0.9134 - val_loss: 0.0153
# Epoch 10/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 41s 69ms/step - accuracy: 0.9565 - loss: 0.0044 - val_accuracy: 0.9028 - val_loss: 0.0204
# Epoch 11/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.9626 - loss: 0.0035 - val_accuracy: 0.9053 - val_loss: 0.0211
# Epoch 12/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 33s 67ms/step - accuracy: 0.9593 - loss: 0.0041 - val_accuracy: 0.9084 - val_loss: 0.0174
# Epoch 13/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 34s 67ms/step - accuracy: 0.9678 - loss: 0.0032 - val_accuracy: 0.9206 - val_loss: 0.0109
# Epoch 14/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 33s 67ms/step - accuracy: 0.9715 - loss: 0.0028 - val_accuracy: 0.9296 - val_loss: 0.0130
# Epoch 15/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 43s 70ms/step - accuracy: 0.9742 - loss: 0.0025 - val_accuracy: 0.9463 - val_loss: 0.0096
# Epoch 16/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.9717 - loss: 0.0030 - val_accuracy: 0.9398 - val_loss: 0.0102
# Epoch 17/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 34s 67ms/step - accuracy: 0.9712 - loss: 0.0025 - val_accuracy: 0.9382 - val_loss: 0.0117
# Epoch 18/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.9732 - loss: 0.0025 - val_accuracy: 0.9312 - val_loss: 0.0136
# Epoch 19/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.9767 - loss: 0.0024 - val_accuracy: 0.9316 - val_loss: 0.0135
# Epoch 20/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 42s 65ms/step - accuracy: 0.9802 - loss: 0.0018 - val_accuracy: 0.9337 - val_loss: 0.0127
# Epoch 21/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9781 - loss: 0.0022 - val_accuracy: 0.9531 - val_loss: 0.0084
# Epoch 22/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 65ms/step - accuracy: 0.9815 - loss: 0.0016 - val_accuracy: 0.9409 - val_loss: 0.0116
# Epoch 23/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9792 - loss: 0.0018 - val_accuracy: 0.9364 - val_loss: 0.0118
# Epoch 24/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.9830 - loss: 0.0016 - val_accuracy: 0.9425 - val_loss: 0.0134
# Epoch 25/25
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9833 - loss: 0.0016 - val_accuracy: 0.9567 - val_loss: 0.0097
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step
#
# --- CLASSIFICATION REPORT ---
#               precision    recall  f1-score   support
#
#       Bridge       0.99      0.97      0.98       569
#          CMP       0.86      0.97      0.91       638
#        Clean       0.96      0.96      0.96       309
#        Crack       0.99      0.95      0.97       592
#          LER       0.99      0.97      0.98       557
#         Open       0.95      0.98      0.96       561
#        Other       0.96      0.95      0.96       630
#          Via       0.99      0.92      0.95       577
#
#     accuracy                           0.96      4433
#    macro avg       0.96      0.96      0.96      4433
# weighted avg       0.96      0.96      0.96      4433
#
# 💾 Converting to TFLite...
# Saved artifact at '/tmp/tmpzo50l4yb'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 1), dtype=tf.float32, name='keras_tensor_330')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   139852361236560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139852361237328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319039184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319043792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319044752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319042256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319042448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319043984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319044560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319044368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319039760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319040528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319043216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319040336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319038224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319040720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319038608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600992464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600992848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319044944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853319043408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600992656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600993616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600993424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600993040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600994768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600994192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600994384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600994576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600993808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600995728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600995152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600995344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600995536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600993232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600996688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600996112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600996304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600996496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600994000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600997648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600997072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600997264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600997456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600994960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600998608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600998032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600998224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600998416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600995920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600999568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600998992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600999184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600999376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600996880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601000528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600999952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601000144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601000336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600997840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601001488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601000912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601001104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601001296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600998800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601002448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601001872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601002064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601002256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849600999760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601003408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601002832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601003024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601003216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601000720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601004368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601003792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601003984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601004176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601001680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601005328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601004752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601004944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601005136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601002640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601006288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601005712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601005904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601006096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601003600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601007248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601006672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601005520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601007056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601006864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601006480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601004560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530000400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530000208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849601007440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530000976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849529999632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530000592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530000784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849529999824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530001936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530001360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530001552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530001744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849529999440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530002896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530002320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530002512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530002704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530000016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530003856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530003280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530003472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530003664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530001168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530004816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530004240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530004432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530004624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530002128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530005776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530005200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530005392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530005584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530003088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530006736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530006160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530006352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530006544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530004048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530007696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530007120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530007312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530007504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530005008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530008656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530008080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530008272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530008464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530005968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530009616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530009040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530009232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530009424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530006928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530010576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530010000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530010192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530010384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530007888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530011536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530010960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530011152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530011344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530008848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530012496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530011920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530012112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530012304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530009808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530013456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530012880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530013072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530013264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530010768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530014416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530013840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530014032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530014224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530011728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530015376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530014800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530013648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530015184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530014992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530014608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530012688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251035216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251035408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139849530015568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251036752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251035792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251036368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251036560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251036176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251037712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251037136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251037328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251037520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251035984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251038672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251038096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251038288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251038480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251035600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251039632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251039056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251039248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251039440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251036944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251040592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251040016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251040208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251040400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251037904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251041552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251040976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251041168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251041360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251038864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251042512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251041936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251042128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251042320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251039824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251043472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251042896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251043088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251043280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251040784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251044432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251043856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251044048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251044240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251041744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251045392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251044816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251045008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251045200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251042704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251046352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251045776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251045968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251046160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251043664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251047312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251046736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251046928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251047120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251044624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251048272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251047696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251047888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251048080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251045584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251049232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251048656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251048848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251049040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251046544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251050192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251049616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251049808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251050000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251047504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251051152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251050768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139853251050960: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# ✅ MobileNetV2_Focal_HardMiner Complete!
